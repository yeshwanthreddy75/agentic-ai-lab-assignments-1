# %% [markdown]
# <a href="https://colab.research.google.com/github/Revanthpendyala02/agentic-ai-lab/blob/master/Assignment_2_Research_Report_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-google-genai duckduckgo-search
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.5/571.5 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 81.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 16.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.

# %%
from google.colab import userdata

GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

print("Gemini key loaded:", GEMINI_API_KEY is not None)
# Out:
# Gemini key loaded: True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    google_api_key=GEMINI_API_KEY
)

print("Gemini connected successfully.")
# Out:
# Gemini connected successfully.

# %%
response = llm.invoke(
    "Explain Artificial Intelligence in one sentence."
)

print(response.content)
# Out:
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': 'Artificial Intelligence is a branch of computer science that enables machines to simulate human intelligence, allowing them to learn from data, reason through problems, and perform tasks autonomously.', 'extras': {'signature': '...'}}]

# %%
from ddgs import DDGS

def web_search(query, max_results=5):
    results = []

    with DDGS() as ddgs:
        search_results = ddgs.text(
            query,
            max_results=max_results
        )

        for result in search_results:
            results.append({
                "title": result["title"],
                "url": result["href"],
                "content": result["body"]
            })

    return results
# Out:
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# !pip install -q ddgs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 74.3 MB/s eta 0:00:00

# %%
from ddgs import DDGS

print("DDGS installed successfully!")
# Out:
# DDGS installed successfully!

# %%
def web_search(query, max_results=5):
    results = []

    with DDGS() as ddgs:
        search_results = ddgs.text(
            query,
            max_results=max_results
        )

        for result in search_results:
            results.append({
                "title": result["title"],
                "url": result["href"],
                "content": result["body"]
            })

    return results

# %%
results = web_search("agentic AI", 5)

for r in results:
    print(r["title"])
    print(r["url"])
    print()
# Out:
# Agentic AI
# https://en.wikipedia.org/wiki/Agentic_AI
#
# Agentic AI
# https://grokipedia.com/page/agentic-ai
#
# What the heck: Agentic AI??? : r/sysadmin - Reddit
# https://www.reddit.com/r/sysadmin/comments/1s3zcjg/what_the_heck_agentic_ai/
#
# What is Agentic AI? | Arfan Jaffar - LinkedIn
# https://www.linkedin.com/posts/arfan-jaffar-07277b1a_what-is-agentic-ai-agentic-ai-refers-to-activity-7384159320168411136-7u89
#
# Why Agentic AI is the Future of AI - Intel Community
# https://community.intel.com/t5/Blogs/Tech-Innovation/Artificial-Intelligence-AI/Why-Agentic-AI-is-the-Future-of-AI/post/1683515

# %%
def research_topic(topic):

    results = web_search(topic, 5)

    research_data = ""

    for i, result in enumerate(results, 1):
        research_data += f"""
Source {i}
Title: {result['title']}
URL: {result['url']}
Content: {result['content']}
-------------------------
"""

    prompt = f"""
You are a research agent.

Research Topic:
{topic}

Using only the sources provided below, create a concise research summary.

Include:
1. Definition
2. Key Concepts
3. Applications
4. Advantages
5. Limitations
6. Future Scope

Do not invent information.

Sources:
{research_data}
"""

    response = llm.invoke(prompt)

    content = response.content

    if isinstance(content, list):
        content = "\n".join(
            item.get("text", "")
            for item in content
            if isinstance(item, dict) and item.get("type") == "text"
        )

    return content, results

# %%
from google.colab import userdata

GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

print("Gemini key loaded:", GEMINI_API_KEY is not None)
# Out:
# Gemini key loaded: True

# %%
# !pip install -q langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.5/571.5 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 14.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    google_api_key=GEMINI_API_KEY
)

print("Gemini connected successfully!")
# Out:
# Gemini connected successfully!

# %%
response = llm.invoke("Explain Agentic AI in one sentence.")
print(response.content)
# Out:
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': '**Agentic AI** refers to autonomous artificial intelligence systems that can independently plan, make decisions, and execute multi-step actions to achieve complex goals with minimal human intervention.', 'extras': {'signature': '...'}}]

# %%
topic = "Agentic AI"

summary, sources = research_topic(topic)

print("=" * 60)
print("RESEARCH SUMMARY")
print("=" * 60)
print(summary)
# Out:
# ...
# RESEARCH SUMMARY
# ...
# Here is a concise research summary based strictly on the provided sources:
#
# ---
#
# ### **1. Definition**
# Agentic AI refers to an artificial intelligence program or system category capable of pursuing goals, using software or external tools, and taking action with a level of semi- or full autonomy. Unlike traditional "tool-like" or non-agentic AI (such as standard chatbots that perform narrow tasks like answering questions), agentic AI systems can perceive, reason, and act on their own.
#
# ---
#
# ### **2. Key Concepts**
# * **Goal-Directed Behavior:** Ability to autonomously pursue specified goals rather than simply responding to single, narrow prompts.
# * **Environment Interaction & Tool Usage:** Uses external tools, software, and tool interfaces to interact with and modify external environments.
# * **Autonomous Multi-Step Tasks:** Capable of executing complex, multi-step actions independently.
# ...

# %%
report = generate_report(topic, summary, sources)

print("=" * 60)
print("FINAL RESEARCH REPORT")
print("=" * 60)
print(report)
# Out:
# ...
# FINAL RESEARCH REPORT
# ...
# # Agentic AI
#
# ## 1. Introduction
# Artificial intelligence is undergoing a transition from passive, conversational interfaces toward autonomous, action-driven systems. Agentic AI represents this shift, moving beyond narrow tool-like interactions to systems capable of perceiving, reasoning, and executing tasks autonomously.
#
# ## 2. Definition
# Agentic AI refers to an artificial intelligence program or system category capable of pursuing goals, utilizing software or external tools, and taking action with semi- or full autonomy. Unlike traditional, non-agentic AI—such as standard chatbots limited to narrow tasks like answering questions—agentic AI systems can perceive, reason, and act independently.
#
# ## 3. Key Concepts
# * **Goal-Directed Behavior:** The ability to autonomously pursue specified goals rather than simply responding to single, narrow prompts.
# ...

# %%
topic = input("Enter research topic: ")

summary, sources = research_topic(topic)

report = generate_report(topic, summary, sources)

print("\n" + "=" * 60)
print("RESEARCH REPORT")
print("=" * 60)
print(report)
# Out:
# Enter research topic: machine learning
#
# ...
# RESEARCH REPORT
# ...
# # machine learning
#
# ## 1. Introduction
# Machine learning (ML) is a core field within artificial intelligence focused on developing algorithms that learn from data and experience. By relying on mathematical and statistical foundations, machine learning enables computer systems to identify data patterns, adapt through experience, and execute tasks autonomously without needing step-by-step explicit programming from developers.
#
# ## 2. Definition
# Machine learning is defined as a field of study within artificial intelligence focused on algorithms that analyze and learn from sample data or experience. This enables computers to identify patterns, learn independently, generalize to unseen data, and generate predictions or strategies to execute tasks without explicit programming by a developer.
#
# ## 3. Key Concepts
# ...
